# %% [markdown]
# <a href="https://www.kaggle.com/code/nghiemdinhnam/vffinder-retrain?scriptVersionId=173123719" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git config --global --unset https.proxy
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !mkdir Model
# !mkdir -p Data/result
# Out:
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /tmp/pip-req-build-sboy01xv did not run successfully.
#   │ exit code: 128
#   ╰─> [1 lines of output]
#       fatal: unable to access 'https://github.com/pyg-team/pytorch_geometric.git/': Could not resolve host: github.com
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /tmp/pip-req-build-sboy01xv did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !git clone https://github.com/DinhNam99/vffinder_retrain.git
# Out:
# Cloning into 'vffinder_retrain'...
# fatal: unable to access 'https://github.com/DinhNam99/vffinder_retrain.git/': Could not resolve host: github.com

# %%
# !python vffinder_retrain/Main_VULJIT_Detection.py \
--graph_dir='/kaggle/input/embedding-ast-silent/embedding_ast'  \
--train_file='/kaggle/input/data-slient-fix/cross_train.txt' \
--test_file='/kaggle/input/data-slient-fix/cross_test.txt' \
--model_dir='/kaggle/working/Model' \
--max_epochs=50 \
--model_name='gat' \
--hidden_size=32 \
--GNN_type="GAT"
# Out:
# python: can't open file '/kaggle/working/vffinder_retrain/Main_VULJIT_Detection.py': [Errno 2] No such file or directory
